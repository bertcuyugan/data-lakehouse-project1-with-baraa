# %%
# %sql
DROP TABLE workspace.bronze.crm_prd_info

# %%
df = spark.read.csv('/Volumes/workspace/bronze/source_system/source_crm/prd_info.csv', header=True, inferSchema=True)

df.display()

# %%
(
    df.write
        .mode('overwrite')
        .saveAsTable('workspace.bronze.crm_prd_info')
)

# %%
# %sql
SELECT
* 
FROM workspace.bronze.crm_prd_info
