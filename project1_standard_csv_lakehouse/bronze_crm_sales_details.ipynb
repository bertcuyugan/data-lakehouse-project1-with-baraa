# %%
df = (
    spark.read
    .option("header", "True")
    .option("inferSchema", "True")
    .csv("/Volumes/workspace/bronze/source_system/source_crm/sales_details.csv")
)

df.display()

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.sales_details_info")

# %%
# %sql
select 
*
from workspace.bronze.sales_details_info
