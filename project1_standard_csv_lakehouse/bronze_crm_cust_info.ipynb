# %%
df=spark.read.csv('/Volumes/workspace/bronze/source_system/source_crm/cust_info.csv',header=True,inferSchema=True)
display(df)

# %%
df.write.mode('overwrite').saveAsTable('workspace.bronze.crm_cust_info')

# %%
# %sql
SELECT 
* 
FROM workspace.bronze.crm_cust_info
